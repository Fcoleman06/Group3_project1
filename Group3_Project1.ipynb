# %%
#-------------------------------
# Dependencies and Setup
#-------------------------------

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st



#-------------------------------
# Dependencies and Setup
#-------------------------------

arrest_data = "Resources/NYPD_Arrest_Data_2023.csv"
borough_zip_data = "Resources/nyc_zip_borough_neighborhoods.csv"
mental_fac_data = "Resources/NYS-Mental-Facilities.csv"


#-------------------------------
# Create Dataframes 
#-------------------------------

arrest_df = pd.read_csv(arrest_data)
zip_df = pd.read_csv(borough_zip_data)
menta_fac_df = pd.read_csv(mental_fac_data)

# %%
#-------------------------------
# Read Menta_fac columns
#-------------------------------

menta_fac_df.head()
# Out:
#    index   Row Created Date Time                          Sponsor Name  \
# 0      0  12/19/2017 02:08:00 PM  Northern Rivers Family Services Inc.
# 1      1  12/19/2017 02:08:00 PM            Capital Area Peer Services
# 2      2  12/19/2017 02:08:00 PM   Capital District Psychiatric Center
# 3      3  12/19/2017 02:08:00 PM   Capital District Psychiatric Center
# 4      4  12/19/2017 02:08:00 PM                          Equinox Inc.
#
#     Sponsor Code                          Agency Name   Agency Code  \
# 0         452099      Parsons Child and Family Center         40400
# 1         630099           Capital Area Peer Services         11620
# 2          72099  Capital District Psychiatric Center         90200
# 3          72099  Capital District Psychiatric Center         90200
# 4         280099                         Equinox Inc.         14510
#
#                          Facility Name   Facility Code  \
# 0      Parsons Child and Family Center            6223
# 1           Capital Area Peer Services            8632
# 2  Capital District Psychiatric Center              24
# 3  Capital District Psychiatric Center              24
# 4                         Equinox Inc.            7524
#
#                                         Program Name   Program Code  ...  \
# 0                                 Orissa Healy House            430  ...
# 1                   Clinton Avenue Apartment Program            430  ...
# 2                                       Jansen House            861  ...
# 3                         New Scotland Residence TPP            235  ...
# 4  Clearview Supp Housing/PC Long Stay Albany Cou...            631  ...
#
#    Program Zip  Operating Certificate Required?  Program Tier  \
# 0          NaN                                Y           NaN
# 1          NaN                                Y           1.0
# 2          NaN                                Y           1.0
# 3          NaN                                Y           1.0
# 4          NaN                                N           NaN
#
#    Operating Certificate Duration  Program County  Program Region  \
# 0                            36.0          Albany    Hudson River
# 1                            36.0          Albany    Hudson River
# 2                            36.0          Albany    Hudson River
# 3                            36.0          Albany    Hudson River
# 4                             NaN          Albany    Hudson River
#
#                Program Type Description  Program Category Description  \
# 0                      Crisis Residence                     Emergency
# 1                     Apartment/Support                   Residential
# 2                  Congregate/Treatment                   Residential
# 3                  Congregate/Treatment                   Residential
# 4  Supported Housing Community Services                   Residential
#
#    Program Subcategory Description  Location
# 0                           Crisis       NaN
# 1                  Support Program       NaN
# 2                Treatment Program       NaN
# 3                Treatment Program       NaN
# 4               Unlicensed Housing       NaN
#
# [5 rows x 27 columns]

# %%
#-------------------------------
# Create new dataframe without row created date time/sponsor name/code, agency name/code, program name/code
#-------------------------------

reduced_df = menta_fac_df[["index"]]
reduced_df.head()

# reduced_df = menta_fac_df[["index", "Row", "Sponsor Name", "Agency Name", "Facility Name", "Program Name", "Populations Served", "Agency Phone", "Program Phone", "Program Address 1", "Program Address 2", "Program City", "Program State", "Program Zip", "Operating Certificate Required?", "Program Tier", "Operating Certificate Duration", "Program County", "Program Region", "Program Type Description", "Program Category Description", "Program Subcategory Description", "Location"]]
# reduced_df.head()

menta_fac_df.columns
# Out:
# Index(['index', 'Row Created Date Time', ' Sponsor Name', ' Sponsor Code',
#        ' Agency Name', ' Agency Code', 'Facility Name', ' Facility Code',
#        ' Program Name', ' Program Code', ' Populations Served',
#        ' Agency Phone', ' Program Phone', '  Program Address 1',
#        ' Program Address 2', ' Program City', ' Program State', ' Program Zip',
#        ' Operating Certificate Required?', ' Program Tier',
#        ' Operating Certificate Duration', ' Program County', ' Program Region',
#        ' Program Type Description', ' Program Category Description',
#        ' Program Subcategory Description', 'Location'],
#       dtype='object')

# %%
reduced_mf_df = menta_fac_df[["index", 'Row Created Date Time', ' Sponsor Name',
       ' Agency Name', 'Facility Name', ' Facility Code',
       ' Program Name', ' Populations Served',
       ' Agency Phone', ' Program Phone', '  Program Address 1',
       ' Program Address 2', ' Program City', ' Program State', ' Program Zip',
       ' Operating Certificate Required?', ' Program Tier',
       ' Operating Certificate Duration', ' Program County', ' Program Region',
       ' Program Type Description', ' Program Category Description',
       ' Program Subcategory Description', 'Location']]
reduced_mf_df.head()
# Out:
#    index   Row Created Date Time                          Sponsor Name  \
# 0      0  12/19/2017 02:08:00 PM  Northern Rivers Family Services Inc.
# 1      1  12/19/2017 02:08:00 PM            Capital Area Peer Services
# 2      2  12/19/2017 02:08:00 PM   Capital District Psychiatric Center
# 3      3  12/19/2017 02:08:00 PM   Capital District Psychiatric Center
# 4      4  12/19/2017 02:08:00 PM                          Equinox Inc.
#
#                            Agency Name                        Facility Name  \
# 0      Parsons Child and Family Center      Parsons Child and Family Center
# 1           Capital Area Peer Services           Capital Area Peer Services
# 2  Capital District Psychiatric Center  Capital District Psychiatric Center
# 3  Capital District Psychiatric Center  Capital District Psychiatric Center
# 4                         Equinox Inc.                         Equinox Inc.
#
#     Facility Code                                       Program Name  \
# 0            6223                                 Orissa Healy House
# 1            8632                   Clinton Avenue Apartment Program
# 2              24                                       Jansen House
# 3              24                         New Scotland Residence TPP
# 4            7524  Clearview Supp Housing/PC Long Stay Albany Cou...
#
#    Populations Served   Agency Phone  Program Phone  ...  Program Zip  \
# 0            Children  (518)426-2600  Not Available  ...          NaN
# 1              Adults  (518)427-5056  Not Available  ...          NaN
# 2              Adults  (518)549-6000  Not Available  ...          NaN
# 3              Adults  (518)549-6000  Not Available  ...          NaN
# 4              Adults  (518)435-9931  Not Available  ...          NaN
#
#    Operating Certificate Required?  Program Tier  \
# 0                                Y           NaN
# 1                                Y           1.0
# 2                                Y           1.0
# 3                                Y           1.0
# 4                                N           NaN
#
#    Operating Certificate Duration  Program County  Program Region  \
# 0                            36.0          Albany    Hudson River
# 1                            36.0          Albany    Hudson River
# 2                            36.0          Albany    Hudson River
# 3                            36.0          Albany    Hudson River
# 4                             NaN          Albany    Hudson River
#
#                Program Type Description   Program Category Description  \
# 0                      Crisis Residence                      Emergency
# 1                     Apartment/Support                    Residential
# 2                  Congregate/Treatment                    Residential
# 3                  Congregate/Treatment                    Residential
# 4  Supported Housing Community Services                    Residential
#
#    Program Subcategory Description Location
# 0                           Crisis      NaN
# 1                  Support Program      NaN
# 2                Treatment Program      NaN
# 3                Treatment Program      NaN
# 4               Unlicensed Housing      NaN
#
# [5 rows x 24 columns]

# %%
#-------------------------------
# Create new dataframe with duplicate and missing data
#-------------------------------


clean_mf_df= reduced_mf_df.drop_duplicates(subset=[' Facility Code'], keep='first')

clean_mf_df.head()
# Out:
#    index   Row Created Date Time                          Sponsor Name  \
# 0      0  12/19/2017 02:08:00 PM  Northern Rivers Family Services Inc.
# 1      1  12/19/2017 02:08:00 PM            Capital Area Peer Services
# 2      2  12/19/2017 02:08:00 PM   Capital District Psychiatric Center
# 4      4  12/19/2017 02:08:00 PM                          Equinox Inc.
# 9      9  12/19/2017 02:08:00 PM    Homeless and Travelers Aid Society
#
#                            Agency Name                        Facility Name  \
# 0      Parsons Child and Family Center      Parsons Child and Family Center
# 1           Capital Area Peer Services           Capital Area Peer Services
# 2  Capital District Psychiatric Center  Capital District Psychiatric Center
# 4                         Equinox Inc.                         Equinox Inc.
# 9   Homeless and Travelers Aid Society   Homeless and Travelers Aid Society
#
#     Facility Code                                       Program Name  \
# 0            6223                                 Orissa Healy House
# 1            8632                   Clinton Avenue Apartment Program
# 2              24                                       Jansen House
# 4            7524  Clearview Supp Housing/PC Long Stay Albany Cou...
# 9            8906  HATAS Supp Hsing/STP Forensic Albany Cty - Com...
#
#    Populations Served   Agency Phone  Program Phone  ...  Program Zip  \
# 0            Children  (518)426-2600  Not Available  ...          NaN
# 1              Adults  (518)427-5056  Not Available  ...          NaN
# 2              Adults  (518)549-6000  Not Available  ...          NaN
# 4              Adults  (518)435-9931  Not Available  ...          NaN
# 9              Adults  (518)463-2124  Not Available  ...          NaN
#
#    Operating Certificate Required?  Program Tier  \
# 0                                Y           NaN
# 1                                Y           1.0
# 2                                Y           1.0
# 4                                N           NaN
# 9                                N           NaN
#
#    Operating Certificate Duration  Program County  Program Region  \
# 0                            36.0          Albany    Hudson River
# 1                            36.0          Albany    Hudson River
# 2                            36.0          Albany    Hudson River
# 4                             NaN          Albany    Hudson River
# 9                             NaN          Albany    Hudson River
#
#                Program Type Description   Program Category Description  \
# 0                      Crisis Residence                      Emergency
# 1                     Apartment/Support                    Residential
# 2                  Congregate/Treatment                    Residential
# 4  Supported Housing Community Services                    Residential
# 9  Supported Housing Community Services                    Residential
#
#    Program Subcategory Description Location
# 0                           Crisis      NaN
# 1                  Support Program      NaN
# 2                Treatment Program      NaN
# 4               Unlicensed Housing      NaN
# 9               Unlicensed Housing      NaN
#
# [5 rows x 24 columns]

# %%
#-------------------------------
# Remove Facility Code and Program Zip with no data
#-------------------------------

super_clean_mf_df=clean_mf_df.dropna(subset = [' Program Zip'])

super_clean_mf_df.head()
# Out:
#      index   Row Created Date Time  \
# 177    177  12/19/2017 02:08:00 PM
# 251    251  12/19/2017 02:08:00 PM
# 252    252  12/19/2017 02:08:00 PM
# 272    272  12/19/2017 02:08:00 PM
# 313    313  12/19/2017 02:08:00 PM
#
#                                           Sponsor Name  \
# 177                                 St. Dominic's Home
# 251                    Cayuga Counseling Services Inc.
# 252                Central New York Psychiatric Center
# 272                                 TLC Health Network
# 313  National Alliance for the Mentally Ill of Cham...
#
#                                        Agency Name  \
# 177                             St. Dominic's Home
# 251                Cayuga Counseling Services Inc.
# 252            Central New York Psychiatric Center
# 272                             TLC Health Network
# 313  National Alliance for the Mentally Ill of Cha
#
#                                      Facility Name   Facility Code  \
# 177                             St. Dominic's Home            7159
# 251                Cayuga Counseling Services Inc.            7734
# 252            Central New York Psychiatric Center              43
# 272                             TLC Health Network            8797
# 313  National Alliance for the Mentally Ill of Cha            7497
#
#                                           Program Name    Populations Served  \
# 177  Bronx Family Support Services - Children & Family       Children Adults
# 251   Residential Family Peer Support Partners Program  Children Adolescents
# 252                          Auburn OMH Satellite Unit                Adults
# 272                   TLC Inpatient Mental Health Unit                Adults
# 313                                           OUTREACH                Adults
#
#         Agency Phone  Program Phone  ...  Program Zip  \
# 177    (845)359-3400  (718)295-9112  ...        10548
# 251    (315)253-9795  (315)253-9795  ...        13021
# 252    (315)765-3600  (315)253-9382  ...        13024
# 272    (716)951-7035  (716)951-7239  ...   14081-9716
# 313  (518)561-2685x4  (518)561-2685  ...        12903
#
#      Operating Certificate Required?  Program Tier  \
# 177                                N           NaN
# 251                                N           NaN
# 252                                N           NaN
# 272                                Y           NaN
# 313                                N           NaN
#
#      Operating Certificate Duration  Program County    Program Region  \
# 177                             NaN           Bronx     New York City
# 251                             NaN          Cayuga  Central New York
# 252                             NaN          Cayuga  Central New York
# 272                            36.0      Chautauqua  Western New York
# 313                             NaN         Clinton  Central New York
#
#                              Program Type Description  \
# 177       Family Support Services - Children & Family
# 251       Family Support Services - Children & Family
# 252         Prison-based Forensic Mental Health Units
# 272  Inpatient Psychiatric Unit of a General Hospital
# 313                                          Outreach
#
#       Program Category Description  \
# 177                        Support
# 251                        Support
# 252                        Support
# 272                      Inpatient
# 313                        Support
#
#                       Program Subcategory Description  \
# 177                                   General Support
# 251                                   General Support
# 252                                         Forensics
# 272  Inpatient Psychiatric Unit of a General Hospital
# 313                                   General Support
#
#                                        Location
# 177    One Fordham Plaza\r\nBronx, NY 10548\r\n
# 251                                         NaN
# 252  135 W State Street\r\nAuburn, NY 13024\r\n
# 272     845 Routes\r\nIrving, NY 14081-9716\r\n
# 313        304 New\r\nPlattsburgh, NY 12903\r\n
#
# [5 rows x 24 columns]

# %%
#-------------------------------
# Read Arrest_df columns
#-------------------------------

arrest_df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                      PD_DESC  KY_CD  \
# 0   261209118  01/01/2023    109     ASSAULT 2,1,UNCLASSIFIED  106.0
# 1   262984267  02/03/2023    515  CONTROLLED SUBSTANCE,SALE 3  117.0
# 2   263664549  02/15/2023    105            STRANGULATION 1ST  106.0
# 3   261345231  01/04/2023    105            STRANGULATION 1ST  106.0
# 4   263536618  02/13/2023    109     ASSAULT 2,1,UNCLASSIFIED  106.0
#
#          OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0   FELONY ASSAULT  PL 1200501          F           K               77
# 1  DANGEROUS DRUGS  PL 2203901          F           K               73
# 2   FELONY ASSAULT  PL 1211200          F           K               62
# 3   FELONY ASSAULT  PL 1211200          F           M               32
# 4   FELONY ASSAULT  PL 12005WX          F           K               71
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# 0                  0     45-64        F     BLACK      999335      186085
# 1                  0     25-44        M     BLACK     1009318      178259
# 2                  0     25-44        M     WHITE      982272      158771
# 3                  0     25-44        M     BLACK      999899      238684
# 4                  0     25-44        M     BLACK     1001437      183080
#
#     Latitude  Longitude
# 0  40.677426 -73.945615
# 1  40.655923 -73.909650
# 2  40.602468 -74.007120
# 3  40.821797 -73.943457
# 4  40.669175 -73.938042

# %%
#-------------------------------
# Create new dataframe without 
#-------------------------------

reduced_ad_df = menta_fac_df[["index"]]
reduced_ad_df.head()
